# %% [markdown]
# <a href="https://colab.research.google.com/github/cadv1984/portafolio/blob/main/inmuebles_cdmx.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PANDAS

# %% [markdown]
# # IMPORTANDO LA BD

# %%
import pandas as pd

ruta = 'https://gist.githubusercontent.com/ahcamachod/a572cfcc2527046db93101f88011b26e/raw/ffb13f45a79d31223e645611a119397dd127ee3c/alquiler.csv'


pd.read_csv(ruta,sep=';')
# Out:
#                           Tipo               Colonia  Habitaciones  Garages  \
# 0                     Cocineta               Condesa             1        0
# 1                         Casa               Polanco             2        0
# 2      Conjunto Comercial/Sala              Santa Fe             0        4
# 3                 Departamento      Centro Histórico             1        0
# 4                 Departamento             Del Valle             1        0
# ...                        ...                   ...           ...      ...
# 25116  Cochera/Estacionamiento      Centro Histórico             0        0
# 25117                 Cocineta      Centro Histórico             0        0
# 25118             Departamento               Mixcoac             2        1
# 25119             Departamento  Lomas de Chapultepec             2        0
# 25120  Conjunto Comercial/Sala      Centro Histórico             0        0
#
#        Suites  Area    Valor  Condominio  Impuesto
# ...

# %%
datos = pd.read_csv(ruta,sep=';')

datos
# Out:
#                           Tipo               Colonia  Habitaciones  Garages  \
# 0                     Cocineta               Condesa             1        0
# 1                         Casa               Polanco             2        0
# 2      Conjunto Comercial/Sala              Santa Fe             0        4
# 3                 Departamento      Centro Histórico             1        0
# 4                 Departamento             Del Valle             1        0
# ...                        ...                   ...           ...      ...
# 25116  Cochera/Estacionamiento      Centro Histórico             0        0
# 25117                 Cocineta      Centro Histórico             0        0
# 25118             Departamento               Mixcoac             2        1
# 25119             Departamento  Lomas de Chapultepec             2        0
# 25120  Conjunto Comercial/Sala      Centro Histórico             0        0
#
#        Suites  Area    Valor  Condominio  Impuesto
# ...

# %%
datos.head()
# Out:
#                       Tipo           Colonia  Habitaciones  Garages  Suites  \
# 0                 Cocineta           Condesa             1        0       0
# 1                     Casa           Polanco             2        0       1
# 2  Conjunto Comercial/Sala          Santa Fe             0        4       0
# 3             Departamento  Centro Histórico             1        0       0
# 4             Departamento         Del Valle             1        0       0
#
#    Area    Valor  Condominio  Impuesto
# 0    40   5950.0      1750.0     210.0
# 1   100  24500.0         NaN       NaN
# 2   150  18200.0     14070.0    3888.5
# 3    15   2800.0      1365.0      70.0
# 4    48   2800.0       805.0       NaN

# %%
datos.tail(9)
# Out:
#                           Tipo               Colonia  Habitaciones  Garages  \
# 25112  Conjunto Comercial/Sala      Centro Histórico             0        0
# 25113             Departamento              Coyoacán             3        1
# 25114             Departamento              Narvarte             1        0
# 25115       Casa de Condominio              Santa Fe             5        3
# 25116  Cochera/Estacionamiento      Centro Histórico             0        0
# 25117                 Cocineta      Centro Histórico             0        0
# 25118             Departamento               Mixcoac             2        1
# 25119             Departamento  Lomas de Chapultepec             2        0
# 25120  Conjunto Comercial/Sala      Centro Histórico             0        0
#
#        Suites  Area    Valor  Condominio  Impuesto
# 25112       0    32   2100.0      3622.5     290.5
# 25113       2   150  52500.0      4900.0    2100.0
# 25114       0    28   3500.0      1260.0      87.5
# ...

# %%
datos.head(10)
# Out:
#                       Tipo           Colonia  Habitaciones  Garages  Suites  \
# 0                 Cocineta           Condesa             1        0       0
# 1                     Casa           Polanco             2        0       1
# 2  Conjunto Comercial/Sala          Santa Fe             0        4       0
# 3             Departamento  Centro Histórico             1        0       0
# 4             Departamento         Del Valle             1        0       0
# 5       Casa de Condominio          Santa Fe             5        4       5
# 6  Conjunto Comercial/Sala  Centro Histórico             0        3       0
# 7             Departamento  Centro Histórico             1        0       0
# 8             Departamento           Condesa             1        0       1
# 9                 Cocineta           Condesa             1        0       0
#
#    Area     Valor  Condominio  Impuesto
# 0    40    5950.0      1750.0     210.0
# 1   100   24500.0         NaN       NaN
# ...

# %%
datos.sample(10)
# Out:
#                           Tipo               Colonia  Habitaciones  Garages  \
# 14421                     Casa    Villa de Guadalupe             3        1
# 4737   Conjunto Comercial/Sala      Centro Histórico             0        0
# 9603   Conjunto Comercial/Sala               Polanco             0        0
# 17356             Departamento                  Roma             1        1
# 18567  Conjunto Comercial/Sala              Santa Fe             0        1
# 24448             Departamento  Lomas de Chapultepec             3        2
# 2066   Conjunto Comercial/Sala              Santa Fe             0        6
# 22402             Departamento              Narvarte             3        1
# 7422              Departamento  Lomas de Chapultepec             2        1
# 5066   Conjunto Comercial/Sala               Condesa             0        0
#
#        Suites  Area    Valor  Condominio  Impuesto
# 14421       2    15  24769.5         NaN       NaN
# ...

# %%
type(datos)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # EXPLORACIÓN INICIAL DE LOS DATOS

# %%
datos.sample()
# Out:
#               Tipo               Colonia  Habitaciones  Garages  Suites  Area  \
# 8328  Departamento  Lomas de Chapultepec             4        2       2   200
#
#         Valor  Condominio  Impuesto
# 8328  24500.0     12250.0    1750.0

# %%
datos.shape
# Out:
# (25121, 9)

# %%
datos.columns
# Out:
# Index(['Tipo', 'Colonia', 'Habitaciones', 'Garages', 'Suites', 'Area', 'Valor',
#        'Condominio', 'Impuesto'],
#       dtype='object')

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25121 entries, 0 to 25120
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          25121 non-null  object
#  1   Colonia       25121 non-null  object
#  2   Habitaciones  25121 non-null  int64
#  3   Garages       25121 non-null  int64
#  4   Suites        25121 non-null  int64
#  5   Area          25121 non-null  int64
#  6   Valor         25107 non-null  float64
#  7   Condominio    22495 non-null  float64
#  8   Impuesto      18037 non-null  float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 1.7+ MB

# %%
datos['Tipo']
# Out:
# 0                       Cocineta
# 1                           Casa
# 2        Conjunto Comercial/Sala
# 3                   Departamento
# 4                   Departamento
#                   ...
# 25116    Cochera/Estacionamiento
# 25117                   Cocineta
# 25118               Departamento
# 25119               Departamento
# 25120    Conjunto Comercial/Sala
# Name: Tipo, Length: 25121, dtype: object

# %%
datos[['Habitaciones','Valor']]
# Out:
#        Habitaciones    Valor
# 0                 1   5950.0
# 1                 2  24500.0
# 2                 0  18200.0
# 3                 1   2800.0
# 4                 1   2800.0
# ...             ...      ...
# 25116             0  49000.0
# 25117             0   2800.0
# 25118             2   4900.0
# 25119             2  10500.0
# 25120             0  22750.0
#
# [25121 rows x 2 columns]

# %%
'''
Para practicar los métodos aprendidos a lo largo de esta lección y aprender nuevos, realizaremos algunos análisis utilizando un archivo CSV diferente: alumnos.csv.

Importa el archivo alumnos.csv y almacena su contenido en un DataFrame de Pandas.

Visualiza las primeras 7 filas del DataFrame y las últimas 5.

Verifica la cantidad de filas y columnas en este DataFrame.

Explora las columnas del DataFrame y analiza los tipos de datos presentes en cada columna.

Extra: Calcula algunas estadísticas descriptivas básicas de los datos en el DataFrame (media, desviación estándar, etc.). Pista: busca el método "describe".

Si necesitas ayuda, en la sección "Opinión del Instructor" puedes encontrar algunas formas de resolver los desafíos propuestos anteriormente.


'''

import pandas as pd

doc = 'https://gist.githubusercontent.com/ahcamachod/807a2c1cf6c19108b2b701ea1791ab45/raw/fb84f8b2d8917a89de26679eccdbc8f9c1d2e933/alumnos.csv'

datos2 = pd.read_csv(doc,sep=',')

# %%
datos2. head(7)
# Out:
#     Nombre  Edad  Nota Aprobado
# 0  Alberto    20   7.5     True
# 1      Ana    18   NaN    False
# 2   Camila    27   2.5    False
# 3    David    18   5.0    False
# 4    Brian    21  10.0     True
# 5    Bruna    23   NaN    False
# 6  Daniela    21   7.0     True

# %%
datos2.tail(5)
# Out:
#     Nombre  Edad  Nota   Aprobado
# 13  Miriam    25   9.0       True
# 14   Pablo    37   NaN      False
# 15  Milena    29   7.0       True
# 16   Lucas    33   NaN      False
# 17   Nadia    34   8.0  Verdadero

# %%
datos2.shape
# Out:
# (18, 4)

# %%
datos2.columns
# Out:
# Index(['Nombre', 'Edad', 'Nota', 'Aprobado'], dtype='object')

# %%
datos2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Nombre    18 non-null     object
#  1   Edad      18 non-null     int64
#  2   Nota      12 non-null     float64
#  3   Aprobado  18 non-null     object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 708.0+ bytes

# %%
datos2.describe()
# Out:
#             Edad       Nota
# count  18.000000  12.000000
# mean   25.500000   6.841667
# std     6.070662   2.264532
# min    18.000000   2.500000
# 25%    21.000000   5.450000
# 50%    24.500000   7.000000
# 75%    28.750000   8.250000
# max    37.000000  10.000000

# %%
datos2.dtypes
# Out:
# Nombre       object
# Edad          int64
# Nota        float64
# Aprobado     object
# dtype: object

# %%
datos2['Nombre']
# Out:
# 0      Alberto
# 1          Ana
# 2       Camila
# 3        David
# 4        Brian
# 5        Bruna
# 6      Daniela
# 7       Carlos
# 8       Alicia
# 9       Victor
# 10      Danilo
# 11     Ignacio
# 12    Stephany
# 13      Miriam
# 14       Pablo
# 15      Milena
# 16       Lucas
# 17       Nadia
# Name: Nombre, dtype: object

# %%
datos2[['Nombre','Edad']]
# Out:
#       Nombre  Edad
# 0    Alberto    20
# 1        Ana    18
# 2     Camila    27
# 3      David    18
# 4      Brian    21
# 5      Bruna    23
# 6    Daniela    21
# 7     Carlos    19
# 8     Alicia    35
# 9     Victor    28
# 10    Danilo    21
# 11   Ignacio    24
# 12  Stephany    26
# 13    Miriam    25
# 14     Pablo    37
# 15    Milena    29
# 16     Lucas    33
# 17     Nadia    34

# %%
datos2[['Edad','Nota']]
# Out:
#     Edad  Nota
# 0     20   7.5
# 1     18   NaN
# 2     27   2.5
# 3     18   5.0
# 4     21  10.0
# 5     23   NaN
# 6     21   7.0
# 7     19   6.0
# 8     35   5.6
# 9     28   NaN
# 10    21   NaN
# 11    24   4.5
# 12    26  10.0
# 13    25   9.0
# 14    37   NaN
# 15    29   7.0
# 16    33   NaN
# 17    34   8.0

# %% [markdown]
# # DEMANDAS ML
#
# ¿Cuáles son los valores promedio de alquiler por tipo de propiedad?

# %%
datos.head()
# Out:
#                       Tipo           Colonia  Habitaciones  Garages  Suites  \
# 0                 Cocineta           Condesa             1        0       0
# 1                     Casa           Polanco             2        0       1
# 2  Conjunto Comercial/Sala          Santa Fe             0        4       0
# 3             Departamento  Centro Histórico             1        0       0
# 4             Departamento         Del Valle             1        0       0
#
#    Area    Valor  Condominio  Impuesto
# 0    40   5950.0      1750.0     210.0
# 1   100  24500.0         NaN       NaN
# 2   150  18200.0     14070.0    3888.5
# 3    15   2800.0      1365.0      70.0
# 4    48   2800.0       805.0       NaN

# %%
datos['Valor'].mean()
# Out:
# np.float64(36885.05048392878)

# %%
datos.groupby('Tipo')['Valor'].mean()
# Out:
# Tipo
# Casa                           31453.177064
# Casa Comercial                 54735.841584
# Casa de Condominio             51428.609836
# Casa de Vecindad                5961.740506
# Cochera/Estacionamiento         6995.454545
# Cocineta                        4425.856061
# Conjunto Comercial/Sala        57675.214550
# Departamento                   18683.269431
# Departamento en Hotel          16285.430769
# Edificio Completo             409418.080645
# Estudio                         8400.000000
# Galpón/Depósito/Almacén       299984.140138
# Hotel                          87500.000000
# Industria                     420000.000000
# Loft                            9924.526316
# Loteo/Condominio               92166.666667
# Posada/Chalé                    5180.000000
# Rancho                         38014.375000
# Terreno Estándar              135364.444444
# Tienda en Centro Comercial     32556.785714
# Tienda/Salón                   56263.544252
# ...

# %%
datos.groupby('Tipo').mean(numeric_only=True)
# Out:
#                             Habitaciones    Garages     Suites          Area  \
# Tipo
# Casa                            3.359633   1.897248   1.438532    289.943119
# Casa Comercial                  1.801980   2.118812   0.257426    370.277228
# Casa de Condominio              4.319672   3.555738   3.247541    566.303279
# Casa de Vecindad                1.974684   0.379747   0.215190     79.981013
# Cochera/Estacionamiento         0.064935   1.376623   0.000000     18.662338
# Cocineta                        0.836088   0.020661   0.041322     29.090909
# Conjunto Comercial/Sala         0.047175   2.686323   0.000352    236.323711
# Departamento                    2.504199   1.256367   0.891899    124.014292
# Departamento en Hotel           1.419780   0.969231   0.758242     65.848352
# Edificio Completo               0.405530  11.175115   0.027650   1717.271889
# Estudio                         0.500000   0.250000   0.000000    103.250000
# ...

# %%
datos.groupby('Tipo')['Valor'].mean(numeric_only=True)
# Out:
# Tipo
# Casa                           31453.177064
# Casa Comercial                 54735.841584
# Casa de Condominio             51428.609836
# Casa de Vecindad                5961.740506
# Cochera/Estacionamiento         6995.454545
# Cocineta                        4425.856061
# Conjunto Comercial/Sala        57675.214550
# Departamento                   18683.269431
# Departamento en Hotel          16285.430769
# Edificio Completo             409418.080645
# Estudio                         8400.000000
# Galpón/Depósito/Almacén       299984.140138
# Hotel                          87500.000000
# Industria                     420000.000000
# Loft                            9924.526316
# Loteo/Condominio               92166.666667
# Posada/Chalé                    5180.000000
# Rancho                         38014.375000
# Terreno Estándar              135364.444444
# Tienda en Centro Comercial     32556.785714
# Tienda/Salón                   56263.544252
# ...

# %%
datos.groupby('Tipo')[['Valor']].mean(numeric_only=True).sort_values('Valor')
# Out:
#                                     Valor
# Tipo
# Cocineta                      4425.856061
# Posada/Chalé                  5180.000000
# Casa de Vecindad              5961.740506
# Cochera/Estacionamiento       6995.454545
# Estudio                       8400.000000
# Loft                          9924.526316
# Departamento en Hotel        16285.430769
# Departamento                 18683.269431
# Casa                         31453.177064
# Tienda en Centro Comercial   32556.785714
# Rancho                       38014.375000
# Casa de Condominio           51428.609836
# Casa Comercial               54735.841584
# Tienda/Salón                 56263.544252
# Conjunto Comercial/Sala      57675.214550
# Hotel                        87500.000000
# Loteo/Condominio             92166.666667
# Terreno Estándar            135364.444444
# Galpón/Depósito/Almacén     299984.140138
# Edificio Completo           409418.080645
# Industria                   420000.000000

# %%
df_tipo_precio = datos.groupby('Tipo')[['Valor']].mean(numeric_only=True).sort_values('Valor')

df_tipo_precio.plot(kind='barh',figsize=(12,8), color = 'purple')
# Out:
# <Axes: ylabel='Tipo'>

# %%
df_tipo_precio = datos.groupby('Tipo')[['Valor']].sum().sort_values('Valor')

df_tipo_precio.plot(kind='barh',figsize=(12,8), color = 'purple')
# Out:
# <Axes: ylabel='Tipo'>

# %%
df_tipo_precio = datos.groupby('Tipo')[['Valor']].sum()

df_tipo_precio
# Out:
#                                   Valor
# Tipo
# Casa                         17141981.5
# Casa Comercial               11056640.0
# Casa de Condominio           31371452.0
# Casa de Vecindad               941955.0
# Cochera/Estacionamiento        538650.0
# Cocineta                      3213171.5
# Conjunto Comercial/Sala     327422193.0
# Departamento                275709007.0
# Departamento en Hotel         7409871.0
# Edificio Completo            88843723.5
# Estudio                         33600.0
# Galpón/Depósito/Almacén      86695416.5
# Hotel                          175000.0
# Industria                      420000.0
# Loft                           377132.0
# Loteo/Condominio               276500.0
# Posada/Chalé                     5180.0
# Rancho                         304115.0
# Terreno Estándar              6091400.0
# Tienda en Centro Comercial    6381130.0
# Tienda/Salón                 61664844.5

# %%
datos.Tipo.unique()
# Out:
# array(['Cocineta', 'Casa', 'Conjunto Comercial/Sala', 'Departamento',
#        'Casa de Condominio', 'Edificio Completo', 'Departamento en Hotel',
#        'Tienda/Salón', 'Casa Comercial', 'Casa de Vecindad',
#        'Terreno Estándar', 'Cochera/Estacionamiento', 'Loft',
#        'Galpón/Depósito/Almacén', 'Tienda en Centro Comercial', 'Rancho',
#        'Posada/Chalé', 'Estudio', 'Hotel', 'Loteo/Condominio',
#        'Industria'], dtype=object)

# %%
inmuebles_comerciales = [ 'Conjunto Comercial/Sala',
       'Edificio Completo',
       'Tienda/Salón', 'Casa Comercial',
       'Terreno Estándar', 'Cochera/Estacionamiento',
       'Galpón/Depósito/Almacén', 'Tienda en Centro Comercial',
        'Hotel', 'Loteo/Condominio',
       'Industria']


inmuebles_comerciales
# Out:
# ['Conjunto Comercial/Sala',
#  'Edificio Completo',
#  'Tienda/Salón',
#  'Casa Comercial',
#  'Terreno Estándar',
#  'Cochera/Estacionamiento',
#  'Galpón/Depósito/Almacén',
#  'Tienda en Centro Comercial',
#  'Hotel',
#  'Loteo/Condominio',
#  'Industria']

# %%
datos.query('@inmuebles_comerciales in Tipo')
# Out:
#                           Tipo           Colonia  Habitaciones  Garages  \
# 2      Conjunto Comercial/Sala          Santa Fe             0        4
# 6      Conjunto Comercial/Sala  Centro Histórico             0        3
# 11           Edificio Completo              Roma             0        0
# 24     Conjunto Comercial/Sala          Santa Fe             0        1
# 26     Conjunto Comercial/Sala  Centro Histórico             0        5
# ...                        ...               ...           ...      ...
# 25107  Conjunto Comercial/Sala          Santa Fe             0        1
# 25110  Conjunto Comercial/Sala  Centro Histórico             0        0
# 25112  Conjunto Comercial/Sala  Centro Histórico             0        0
# 25116  Cochera/Estacionamiento  Centro Histórico             0        0
# 25120  Conjunto Comercial/Sala  Centro Histórico             0        0
#
#        Suites  Area     Valor  Condominio  Impuesto
# ...

# %%
datos.query('@inmuebles_comerciales not in Tipo')
# Out:
#                      Tipo               Colonia  Habitaciones  Garages  \
# 0                Cocineta               Condesa             1        0
# 1                    Casa               Polanco             2        0
# 3            Departamento      Centro Histórico             1        0
# 4            Departamento             Del Valle             1        0
# 5      Casa de Condominio              Santa Fe             5        4
# ...                   ...                   ...           ...      ...
# 25114        Departamento              Narvarte             1        0
# 25115  Casa de Condominio              Santa Fe             5        3
# 25117            Cocineta      Centro Histórico             0        0
# 25118        Departamento               Mixcoac             2        1
# 25119        Departamento  Lomas de Chapultepec             2        0
#
#        Suites  Area    Valor  Condominio  Impuesto
# 0           0    40   5950.0      1750.0     210.0
# ...

# %%
df = datos.query('@inmuebles_comerciales not in Tipo')
df.head()
# Out:
#                  Tipo           Colonia  Habitaciones  Garages  Suites  Area  \
# 0            Cocineta           Condesa             1        0       0    40
# 1                Casa           Polanco             2        0       1   100
# 3        Departamento  Centro Histórico             1        0       0    15
# 4        Departamento         Del Valle             1        0       0    48
# 5  Casa de Condominio          Santa Fe             5        4       5   750
#
#      Valor  Condominio  Impuesto
# 0   5950.0      1750.0     210.0
# 1  24500.0         NaN       NaN
# 3   2800.0      1365.0      70.0
# 4   2800.0       805.0       NaN
# 5  77000.0         NaN       NaN

# %%
df_tipo_precio = df.groupby('Tipo')[['Valor']].mean().sort_values('Valor')

df_tipo_precio.plot(kind='barh',figsize=(12,8), color = 'purple')
# Out:
# <Axes: ylabel='Tipo'>

# %% [markdown]
# ```
# # Esto tiene formato de código
# ```
#
# # Porcentaje de cada tipo de inmueble presente en la base de datos

# %%
df.Tipo.unique()
# Out:
# array(['Cocineta', 'Casa', 'Departamento', 'Casa de Condominio',
#        'Departamento en Hotel', 'Casa de Vecindad', 'Loft', 'Rancho',
#        'Posada/Chalé', 'Estudio'], dtype=object)

# %%
df.Tipo.value_counts()
# Out:
# Tipo
# Departamento             14764
# Cocineta                   726
# Casa de Condominio         610
# Casa                       545
# Departamento en Hotel      455
# Casa de Vecindad           158
# Loft                        38
# Rancho                       8
# Estudio                      4
# Posada/Chalé                 1
# Name: count, dtype: int64

# %%
df.Tipo.value_counts(normalize=True)
# Out:
# Tipo
# Departamento             0.852967
# Cocineta                 0.041943
# Casa de Condominio       0.035242
# Casa                     0.031487
# Departamento en Hotel    0.026287
# Casa de Vecindad         0.009128
# Loft                     0.002195
# Rancho                   0.000462
# Estudio                  0.000231
# Posada/Chalé             0.000058
# Name: proportion, dtype: float64

# %%
porc_tipo = df.Tipo.value_counts(normalize=True).to_frame()

porc_tipo.plot(kind='barh',figsize=(12,8), color = 'green',xlabel='Tipo',ylabel='Porcentaje')
# Out:
# <Axes: xlabel='Tipo', ylabel='Porcentaje'>

# %%
df.query('Tipo == "Departamento"')
df.head(2)
# Out:
#        Tipo  Colonia  Habitaciones  Garages  Suites  Area    Valor  \
# 0  Cocineta  Condesa             1        0       0    40   5950.0
# 1      Casa  Polanco             2        0       1   100  24500.0
#
#    Condominio  Impuesto
# 0      1750.0     210.0
# 1         NaN       NaN

# %%
df.shape
# Out:
# (17309, 9)

# %%
df = df.query('Tipo == "Departamento"')

df.head()
# Out:
#             Tipo           Colonia  Habitaciones  Garages  Suites  Area  \
# 3   Departamento  Centro Histórico             1        0       0    15
# 4   Departamento         Del Valle             1        0       0    48
# 7   Departamento  Centro Histórico             1        0       0    36
# 8   Departamento           Condesa             1        0       1    40
# 10  Departamento           Condesa             4        3       1   243
#
#       Valor  Condominio  Impuesto
# 3    2800.0      1365.0      70.0
# 4    2800.0       805.0       NaN
# 7    4200.0         NaN       NaN
# 8    7000.0      1963.5     175.0
# 10  45500.0      7000.0    2810.5

# %%
df.Tipo.value_counts(normalize=True)
# Out:
# Tipo
# Departamento    1.0
# Name: proportion, dtype: float64

# %%
'''
El equipo de ML ha llegado con algunas demandas de última hora que debemos resolver en este momento de análisis exploratorio. Estas demandas son las siguientes:

Calcular el promedio de habitaciones por departamento.

Verificar cuántas colonias únicas existen en nuestra base de datos.

Analizar qué colonias tienen el promedio de alquiler más alto.

Crear un gráfico de barras horizontales que muestre las 5 colonias con los promedios de alquiler más altos.

Si necesitas ayuda, en la sección "Opinión del Instructor" puedes encontrar algunas formas de resolver los desafíos propuestos anteriormente.

'''

datos3 = datos.groupby('Tipo')[['Habitaciones']].mean(numeric_only=True).sort_values('Habitaciones')

datos3
# Out:
#                             Habitaciones
# Tipo
# Industria                       0.000000
# Loteo/Condominio                0.000000
# Tienda/Salón                    0.011840
# Conjunto Comercial/Sala         0.047175
# Tienda en Centro Comercial      0.055838
# Cochera/Estacionamiento         0.064935
# Terreno Estándar                0.066667
# Galpón/Depósito/Almacén         0.069204
# Edificio Completo               0.405530
# Estudio                         0.500000
# Cocineta                        0.836088
# Loft                            1.078947
# Departamento en Hotel           1.419780
# Casa Comercial                  1.801980
# Casa de Vecindad                1.974684
# Departamento                    2.504199
# Casa                            3.359633
# Casa de Condominio              4.319672
# Rancho                          5.125000
# Posada/Chalé                   23.000000
# Hotel                          25.500000

# %%
datos3 = datos['Colonia'].value_counts()

datos3

datos3
# Out:
# Colonia
# Santa Fe                6263
# Condesa                 3309
# Centro Histórico        3263
# Coyoacán                2233
# Lomas de Chapultepec    1478
#                         ...
# San Mateo                  4
# Xochimilco                 4
# El Arenal                  2
# Las Aguilas                2
# Pedregal                   1
# Name: count, Length: 88, dtype: int64

# %%
datos3 = datos.groupby('Colonia')[['Valor']].mean(numeric_only=True).sort_values('Valor')

datos4 = datos3.tail(5)

datos4
# Out:
#                               Valor
# Colonia
# Villa de Cortés       135737.411765
# Santa Marta Acatitla  166048.105263
# La Merced             213292.770833
# Nativitas             244684.395062
# San Juan Xalpa        420926.739130

# %%
datos4.plot(kind='barh',figsize=(12,8), color = 'green',xlabel='Colonia',ylabel='Promedio Alquiler')
# Out:
# <Axes: xlabel='Colonia', ylabel='Promedio Alquiler'>

# %%
df
# Out:
#                Tipo               Colonia  Habitaciones  Garages  Suites  \
# 3      Departamento      Centro Histórico             1        0       0
# 4      Departamento             Del Valle             1        0       0
# 7      Departamento      Centro Histórico             1        0       0
# 8      Departamento               Condesa             1        0       1
# 10     Departamento               Condesa             4        3       1
# ...             ...                   ...           ...      ...     ...
# 25111  Departamento  Lomas de Chapultepec             3        0       1
# 25113  Departamento              Coyoacán             3        1       2
# 25114  Departamento              Narvarte             1        0       0
# 25118  Departamento               Mixcoac             2        1       0
# 25119  Departamento  Lomas de Chapultepec             2        0       0
#
#        Area    Valor  Condominio  Impuesto
# 3        15   2800.0      1365.0      70.0
# ...

# %%
df.isnull()
# Out:
#         Tipo  Colonia  Habitaciones  Garages  Suites   Area  Valor  \
# 3      False    False         False    False   False  False  False
# 4      False    False         False    False   False  False  False
# 7      False    False         False    False   False  False  False
# 8      False    False         False    False   False  False  False
# 10     False    False         False    False   False  False  False
# ...      ...      ...           ...      ...     ...    ...    ...
# 25111  False    False         False    False   False  False  False
# 25113  False    False         False    False   False  False  False
# 25114  False    False         False    False   False  False  False
# 25118  False    False         False    False   False  False  False
# 25119  False    False         False    False   False  False  False
#
#        Condominio  Impuesto
# 3           False     False
# 4           False      True
# 7            True      True
# 8           False     False
# ...

# %%
df.isnull().sum()
# Out:
# Tipo               0
# Colonia            0
# Habitaciones       0
# Garages            0
# Suites             0
# Area               0
# Valor              7
# Condominio       493
# Impuesto        3797
# dtype: int64

# %%
df.fillna(0)
# Out:
#                Tipo               Colonia  Habitaciones  Garages  Suites  \
# 3      Departamento      Centro Histórico             1        0       0
# 4      Departamento             Del Valle             1        0       0
# 7      Departamento      Centro Histórico             1        0       0
# 8      Departamento               Condesa             1        0       1
# 10     Departamento               Condesa             4        3       1
# ...             ...                   ...           ...      ...     ...
# 25111  Departamento  Lomas de Chapultepec             3        0       1
# 25113  Departamento              Coyoacán             3        1       2
# 25114  Departamento              Narvarte             1        0       0
# 25118  Departamento               Mixcoac             2        1       0
# 25119  Departamento  Lomas de Chapultepec             2        0       0
#
#        Area    Valor  Condominio  Impuesto
# 3        15   2800.0      1365.0      70.0
# ...

# %%
df = df.fillna(0)

df.isnull().sum()
# Out:
# Tipo            0
# Colonia         0
# Habitaciones    0
# Garages         0
# Suites          0
# Area            0
# Valor           0
# Condominio      0
# Impuesto        0
# dtype: int64

# %% [markdown]
# # Remover registros inconsistentes

# %%
df.query('Valor==0 | Condominio==0 ')
# Out:
#                Tipo                 Colonia  Habitaciones  Garages  Suites  \
# 7      Departamento        Centro Histórico             1        0       0
# 49     Departamento                Santa Fe             2        1       1
# 74     Departamento  Ciudad de los Deportes             2        0       0
# 116    Departamento              El Rosedal             2        1       0
# 136    Departamento                Santa Fe             1        1       1
# ...             ...                     ...           ...      ...     ...
# 24721  Departamento                Doctores             2        0       0
# 24736  Departamento                 Condesa             1        0       0
# 24866  Departamento                 Condesa             3        0       0
# 24892  Departamento             Loma Bonita             1        0       0
# 25014  Departamento           Culhuacán CTM             3        0       1
#
#        Area    Valor  Condominio  Impuesto
# ...

# %%
df.query('Valor==0 | Condominio==0 ').index
# Out:
# Index([    7,    49,    74,   116,   136,   185,   199,   432,   504,   527,
#        ...
#        24426, 24555, 24563, 24597, 24671, 24721, 24736, 24866, 24892, 25014],
#       dtype='int64', length=500)

# %%
df_rem = df.query('Valor==0 | Condominio==0 ').index
df.drop(df_rem, axis =0,inplace=True)

# %%
df.drop(df_rem, axis =0,inplace=True)

# %%
df.head()
# Out:
#             Tipo           Colonia  Habitaciones  Garages  Suites  Area  \
# 3   Departamento  Centro Histórico             1        0       0    15
# 4   Departamento         Del Valle             1        0       0    48
# 8   Departamento           Condesa             1        0       1    40
# 10  Departamento           Condesa             4        3       1   243
# 13  Departamento          Santa Fe             2        1       1    67
#
#       Valor  Condominio  Impuesto
# 3    2800.0      1365.0      70.0
# 4    2800.0       805.0       0.0
# 8    7000.0      1963.5     175.0
# 10  45500.0      7000.0    2810.5
# 13   5950.0      2061.5     514.5

# %%
df.Tipo.unique()
# Out:
# array(['Departamento'], dtype=object)

# %%
df.drop('Tipo',axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-3605957385.py in <cell line: 0>()
# ----> 1 df.drop('Tipo',axis=1, inplace=True)
#       2 df.sample(10)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#
# ...

# %%
df.sample(10)
# Out:
#                       Colonia  Habitaciones  Garages  Suites  Area     Valor  \
# 1660                 Coyoacán             3        1       1   160   70000.0
# 10092                    Roma             3        1       1   108   20825.0
# 879                  Coyoacán             4        3       3   480  129500.0
# 11261    Lomas de Chapultepec             4        2       2   250   56000.0
# 437    San Miguel Chapultepec             2        1       0    63    4550.0
# 17128                    Roma             3        1       2    82   15400.0
# 17082                Santa Fe             3        1       1    93    9800.0
# 5604     Bosques de las Lomas             2        0       0    55    7700.0
# 8390                 Coyoacán             3        1       1   170   17500.0
# 5402                  Condesa             2        1       1    93   11200.0
#
#        Condominio  Impuesto
# 1660       8400.0    2313.5
# 10092      4917.5     959.0
# 879       33950.0    7581.0
# ...

# %% [markdown]
# # CREANDO FILTROS

# %% [markdown]
# ## 1.-Apartamentos que tienen 1 dormitorio y un alquiler menor a MXN 4200.

# %%
filtro1 = df['Habitaciones']==1

filtro1
# Out:
# 3         True
# 4         True
# 8         True
# 10       False
# 13       False
#          ...
# 25111    False
# 25113    False
# 25114     True
# 25118    False
# 25119    False
# Name: Habitaciones, Length: 14264, dtype: bool

# %%
filtro2 =  df[filtro1]

filtro2
# Out:
#                     Colonia  Habitaciones  Garages  Suites  Area    Valor  \
# 3          Centro Histórico             1        0       0    15   2800.0
# 4                 Del Valle             1        0       0    48   2800.0
# 8                   Condesa             1        0       1    40   7000.0
# 19                 Narvarte             1        0       0    48   2625.0
# 37         Centro Histórico             1        0       0    27   2625.0
# ...                     ...           ...      ...     ...   ...      ...
# 25090              Coyoacán             1        0       0    55   7000.0
# 25092              Santa Fe             1        1       0    62   5950.0
# 25100  Lomas de Chapultepec             1        1       1    50  15050.0
# 25103               Condesa             1        0       0    50   6825.0
# 25114              Narvarte             1        0       0    28   3500.0
#
#        Condominio  Impuesto
# 3          1365.0      70.0
# ...

# %%
filtro3 = df['Valor'] < 4200

filtro4 =  df[filtro3]


filtro4
# Out:
#                   Colonia  Habitaciones  Garages  Suites  Area   Valor  \
# 3        Centro Histórico             1        0       0    15  2800.0
# 4               Del Valle             1        0       0    48  2800.0
# 19               Narvarte             1        0       0    48  2625.0
# 37       Centro Histórico             1        0       0    27  2625.0
# 61       Centro Histórico             1        1       0    37  3850.0
# ...                   ...           ...      ...     ...   ...     ...
# 25038  Villa de Guadalupe             2        1       0    50  2800.0
# 25051           Nativitas             2        1       0    62  3500.0
# 25065           Nativitas             2        1       0    50  3150.0
# 25095      Lindavista Sur             2        0       0    63  2800.0
# 25114            Narvarte             1        0       0    28  3500.0
#
#        Condominio  Impuesto
# 3          1365.0      70.0
# 4           805.0       0.0
# ...

# %%
filtrofinal = filtro1 & filtro3

df[filtrofinal]
# Out:
#                 Colonia  Habitaciones  Garages  Suites  Area   Valor  \
# 3      Centro Histórico             1        0       0    15  2800.0
# 4             Del Valle             1        0       0    48  2800.0
# 19             Narvarte             1        0       0    48  2625.0
# 37     Centro Histórico             1        0       0    27  2625.0
# 61     Centro Histórico             1        1       0    37  3850.0
# ...                 ...           ...      ...     ...   ...     ...
# 24710         Nativitas             1        0       0    40  3150.0
# 24872        Peralvillo             1        0       1    69  3150.0
# 24880        La Condesa             1        0       0    46  3850.0
# 24943              Roma             1        0       0    21  3500.0
# 25114          Narvarte             1        0       0    28  3500.0
#
#        Condominio  Impuesto
# 3          1365.0      70.0
# 4           805.0       0.0
# 19         2702.0      87.5
# ...

# %%
dffinal = df[filtrofinal]

dffinal
# Out:
#                 Colonia  Habitaciones  Garages  Suites  Area   Valor  \
# 3      Centro Histórico             1        0       0    15  2800.0
# 4             Del Valle             1        0       0    48  2800.0
# 19             Narvarte             1        0       0    48  2625.0
# 37     Centro Histórico             1        0       0    27  2625.0
# 61     Centro Histórico             1        1       0    37  3850.0
# ...                 ...           ...      ...     ...   ...     ...
# 24710         Nativitas             1        0       0    40  3150.0
# 24872        Peralvillo             1        0       1    69  3150.0
# 24880        La Condesa             1        0       0    46  3850.0
# 24943              Roma             1        0       0    21  3500.0
# 25114          Narvarte             1        0       0    28  3500.0
#
#        Condominio  Impuesto
# 3          1365.0      70.0
# 4           805.0       0.0
# 19         2702.0      87.5
# ...

# %% [markdown]
# # 2.-Apartamentos que tienen al menos 2 dormitorios, un alquiler menor a MXN 10500 y una superficie mayor a 70 m².

# %%
filtrar = (df['Habitaciones']>=2)& (df['Valor']<10500 )& (df['Area'] > 70)


df[filtrar]
# Out:
#          Colonia  Habitaciones  Garages  Suites  Area   Valor  Condominio  \
# 14      Narvarte             2        1       0   110  6650.0      2450.0
# 16      Narvarte             2        1       0    78  7000.0      2450.0
# 21          Roma             2        1       0    76  8750.0      2590.0
# 33      Santa Fe             3        1       1    72  8225.0      2100.0
# 58      Santa Fe             3        2       1   104  9100.0      4774.0
# ...          ...           ...      ...     ...   ...     ...         ...
# 25028  Del Valle             2        0       1    90  7700.0      1890.0
# 25062   Santa Fe             2        1       1    72  5950.0      3045.0
# 25063   Narvarte             3        1       0    75  6650.0      3010.0
# 25105   Santa Fe             2        1       1    85  7875.0      5463.5
# 25106   Santa Fe             3        2       0    98  8050.0      3104.5
#
#        Impuesto
# 14        483.0
# 16          0.0
# 21          0.0
# ...

# %% [markdown]
# # GUARDANDO LOS ARCHIVOS

# %%
df.to_csv('inmuebles_ml.csv', index=False)

# %%
df.to_csv('inmuebles_ml.csv', index=False,sep=';')

# %%
dffinal.to_csv('inmuebles_ml2.csv', index=False,sep=';')

# %%
filtrar.to_csv('inmuebles_ml3.csv', index=False,sep=';')

# %%
df.to_csv('inmuebles_ml.csv', index=False,sep=';')

# %%
from google.colab import drive
drive.mount('/content/drive')


df.to_csv('/content/drive/MyDrive/inmuebles_ml.csv', index=False,sep=';')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
dffinal.to_csv('/content/drive/MyDrive/inmuebles_ml2.csv', index=False,sep=';')

# %%
filtrar.to_csv('/content/drive/MyDrive/inmuebles_ml3.csv', index=False,sep=';')

# %%
'''
Para practicar los métodos aprendidos a lo largo de esta lección y aprender nuevos, realizaremos algunos tratamientos y selecciones utilizando un archivo CSV diferente: alumnos.csv.

Este archivo es el mismo que se utilizó para resolver los desafíos de la lección 1 y contiene datos de estudiantes de un curso superior.

Basándonos en esto, resolvamos los problemas propuestos a continuación utilizando los conocimientos adquiridos hasta ahora.

Verifica si la base de datos contiene datos nulos y, en caso de tenerlos, realiza el tratamiento de estos datos nulos de la manera que consideres más coherente con la situación.

Los estudiantes "Alicia" y "Carlos" ya no forman parte del grupo. Por lo tanto, elimínalos de la base de datos.

Aplica un filtro que seleccione solo a los estudiantes que fueron aprobados.

Guarda el DataFrame que contiene solo a los estudiantes aprobados en un archivo CSV llamado "alumnos_aprobados.csv".

Extra: Al revisar las calificaciones de los estudiantes aprobados, notamos que algunas calificaciones eran incorrectas. Las estudiantes que obtuvieron una calificación de 7.0, en realidad tenían un punto extra que no se contabilizó. Por lo tanto, reemplaza las calificaciones de 7.0 en la base de datos por 8.0. Consejo: busca el método replace.

Si necesitas ayuda, en la sección "Opinión del Instructor" puedes encontrar algunas formas de resolver los desafíos propuestos anteriormente.

'''
import pandas as npf

url = 'https://gist.githubusercontent.com/ahcamachod/807a2c1cf6c19108b2b701ea1791ab45/raw/fb84f8b2d8917a89de26679eccdbc8f9c1d2e933/alumnos.csv'

dat = npf.read_csv(url,sep=',')

dat
# Out:
#       Nombre  Edad  Nota   Aprobado
# 0    Alberto    20   7.5       True
# 1        Ana    18   NaN      False
# 2     Camila    27   2.5      False
# 3      David    18   5.0      False
# 4      Brian    21  10.0       True
# 5      Bruna    23   NaN      False
# 6    Daniela    21   7.0       True
# 7     Carlos    19   6.0      False
# 8     Alicia    35   5.6      False
# 9     Victor    28   NaN      False
# 10    Danilo    21   NaN      False
# 11   Ignacio    24   4.5      False
# 12  Stephany    26  10.0       True
# 13    Miriam    25   9.0       True
# 14     Pablo    37   NaN      False
# 15    Milena    29   7.0       True
# 16     Lucas    33   NaN      False
# 17     Nadia    34   8.0  Verdadero

# %%
dff = dat.isnull().sum()
dff
# Out:
# Nombre      0
# Edad        0
# Nota        6
# Aprobado    0
# dtype: int64

# %%
dff = dat.fillna(0)

dff.isnull().sum()

dff
# Out:
#       Nombre  Edad  Nota   Aprobado
# 0    Alberto    20   7.5       True
# 1        Ana    18   0.0      False
# 2     Camila    27   2.5      False
# 3      David    18   5.0      False
# 4      Brian    21  10.0       True
# 5      Bruna    23   0.0      False
# 6    Daniela    21   7.0       True
# 7     Carlos    19   6.0      False
# 8     Alicia    35   5.6      False
# 9     Victor    28   0.0      False
# 10    Danilo    21   0.0      False
# 11   Ignacio    24   4.5      False
# 12  Stephany    26  10.0       True
# 13    Miriam    25   9.0       True
# 14     Pablo    37   0.0      False
# 15    Milena    29   7.0       True
# 16     Lucas    33   0.0      False
# 17     Nadia    34   8.0  Verdadero

# %%
df_rem = dff.query('Nombre=="Alicia" | Nombre=="Carlos" ').index
df_rem
# Out:
# Index([7, 8], dtype='int64')

# %%
dff = dff.drop(df_rem)
dff
# Out:
#       Nombre  Edad  Nota   Aprobado
# 0    Alberto    20   7.5       True
# 1        Ana    18   0.0      False
# 2     Camila    27   2.5      False
# 3      David    18   5.0      False
# 4      Brian    21  10.0       True
# 5      Bruna    23   0.0      False
# 6    Daniela    21   7.0       True
# 9     Victor    28   0.0      False
# 10    Danilo    21   0.0      False
# 11   Ignacio    24   4.5      False
# 12  Stephany    26  10.0       True
# 13    Miriam    25   9.0       True
# 14     Pablo    37   0.0      False
# 15    Milena    29   7.0       True
# 16     Lucas    33   0.0      False
# 17     Nadia    34   8.0  Verdadero

# %%
filtrar = dff['Aprobado']=='True'


dff = dff[filtrar]

dff
# Out:
#       Nombre  Edad  Nota Aprobado
# 0    Alberto    20   7.5     True
# 4      Brian    21  10.0     True
# 6    Daniela    21   7.0     True
# 12  Stephany    26  10.0     True
# 13    Miriam    25   9.0     True
# 15    Milena    29   7.0     True

# %%
from google.colab import drive
drive.mount('/content/drive')


dff.to_csv('/content/drive/MyDrive/alumnos_aprobados.csv', index=False,sep=';')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
